# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# Load image
img = cv2.imread('Animal.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
#Get Dimension
height, width, channels = img_rgb.shape
print(f"Dimensions: {width} x {height}")
# Out:
# Dimensions: 4928 x 3280

# %%
#Count Unique Colors
pixels = img_rgb.reshape(-1,3)
unique_colors = np.unique(pixels, axis=0)
print(f"Number of Unique Colors: {len(unique_colors)}")
# Out:
# Number of Unique Colors: 153298

# %%
brightness = 0.299 * pixels[:, 0] + 0.587 * pixels[:,1] + 0.114 * pixels[:,2]
avg_brightness = np.mean(brightness)
print(f"Average Brightness: {avg_brightness:.2f}")
# Out:
# Average Brightness: 109.47

# %%
#Most Frequent Color
color_counts = Counter(map(tuple, pixels))
most_common_color, count = color_counts.most_commo
