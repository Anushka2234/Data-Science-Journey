# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Animal.jpg')
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')
plt.show()

# %%
import numpy as np
print("Shape:", img.shape)
print("Image dtype:", img.dtype)
# Out:
# Shape: (3280, 4928, 3)
# Image dtype: uint8

# %%
colors = ['red', 'green', 'blue']
for i, color in enumerate(colors):
    plt.hist(img[:, :, i].flatten(), bins=256, color=color, alpha=0.5)
plt.title("RGB Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns

gray = img.mean(axis = 2)
sns.heatmap(gray, cmap='gray')
plt.title("Grayscale Heatmap")
plt.axis('off')
plt.show()

# %%
gray_img = np.mean(img, axis=2)
plt.imshow(gray_img, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()

# %%
negative_img = 255 - img
plt.imshow(negative_img)
plt.title("Negative Image")
plt.axis('off')
plt.show()

# %%
threshold = 128
binary_img = gray_img > threshold
plt.imshow(binary_img, cmap='gray')
plt.title("Threshold Image")
plt.axis('off')
plt.show()

# %%
import pandas as pd

pixels = img.reshape(-1,3)
df = pd.DataFrame(pixels, columns=['Red', 'Green', 'Blue'])
print(df.describe())
# Out:
#                 Red         Green          Blue
# count  1.616384e+07  1.616384e+07  1.616384e+07
# mean   1.080367e+02  1.109722e+02  1.054690e+02
# std    6.982713e+01  4.626400e+01  4.913322e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.000000e+01  7.000000e+01  7.200000e+01
# 50%    1.170000e+02  1.070000e+02  1.100000e+02
# 75%    1.600000e+02  1.530000e+02  1.460000e+02
# max    2.550000e+02  2.550000e+02  2.440000e+02
