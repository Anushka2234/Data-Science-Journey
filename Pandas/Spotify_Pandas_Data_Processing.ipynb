# %%
import pandas as pd

# %%
df = pd.read_csv("light_spotify_dataset.csv")

# %%
df.head()
# Out:
#   artist                   song  emotion  variance Genre  Release Date  \
# 0   ABBA  She's My Kind Of Girl      joy  0.447619   pop          2014
# 1   ABBA       Andante, Andante     love  0.202222   pop          1980
# 2   ABBA         As Good As New  sadness  0.300881   pop          1979
# 3   ABBA                   Bang      joy  0.355000   pop          1975
# 4   ABBA       Bang-A-Boomerang      joy  0.355000   pop          1975
#
#       Key  Tempo  Loudness Explicit  Popularity  Energy  Danceability  \
# 0   F Maj    128     -6.00       No          31      78            56
# 1  A# Maj    102    -10.72       No          59      36            52
# 2   E Maj    139     -5.70       No          50      78            85
# 3   F Maj    132     -3.00       No          52      76            50
# 4   F Maj    132     -3.00       No          52      76            50
#
#    Positiveness  Speechiness  Liveness  Acousticness  Instrumentalness
# 0            60            3        31             7                 0
# 1            38            2         7            68                 0
# 2            97            3         8            20                 2
# 3            89            3        32             3                 0
# 4            89            3        32             3                 0

# %%
df.tail()
# Out:
#                               artist                 song  emotion  variance  \
# 236983                  (Eri Sasaki)      Gate Of Steiner  sadness  0.833514
# 236984             (Elena Tsagrinou)            El Diablo     love  0.833514
# 236985                  (Dima Bilan)              Believe      joy  0.833514
# 236986                   (Ani Lorak)           Shady Lady      joy  0.833514
# 236987    (Alla Pugacheva) & 50 Cent  Позови меня P.I.M.P    anger  0.833514
#
#                           Genre  Release Date     Key  Tempo  Loudness  \
# 236983  Unknown,Unknown,Unknown          2018   D min    148     -6.44
# 236984  Unknown,Unknown,Unknown          2021   A min    114     -7.78
# 236985  Unknown,Unknown,Unknown          2009   C min    134     -6.72
# 236986  Unknown,Unknown,Unknown          2009  F# min    128    -13.00
# 236987  Unknown,Unknown,Unknown          2023   B Maj    175     -7.15
#
#        Explicit  Popularity  Energy  Danceability  Positiveness  Speechiness  \
# 236983       No          41      61            41            37            4
# 236984       No          51      66            66            62           13
# 236985       No          36      73            55            24            5
# 236986       No          37      70            71            77            5
# 236987       No          54      91            42            32            8
#
#         Liveness  Acousticness  Instrumentalness
# 236983        14            20                 0
# 236984        84             0                 0
# 236985        22             5                 0
# 236986         7             5                 0
# 236987        38             0                84

# %%
value_missing = df.isnull().sum()
value_missing[value_missing>0]
# Out:
# song    8
# dtype: int64

# %%
df_c = df.dropna(subset=['song'])

# %%
df_c.isnull().sum()
# Out:
# artist              0
# song                0
# emotion             0
# variance            0
# Genre               0
# Release Date        0
# Key                 0
# Tempo               0
# Loudness            0
# Explicit            0
# Popularity          0
# Energy              0
# Danceability        0
# Positiveness        0
# Speechiness         0
# Liveness            0
# Acousticness        0
# Instrumentalness    0
# dtype: int64

# %%
df_c.dtypes
# Out:
# artist               object
# song                 object
# emotion              object
# variance            float64
# Genre                object
# Release Date          int64
# Key                  object
# Tempo                 int64
# Loudness            float64
# Explicit             object
# Popularity            int64
# Energy                int64
# Danceability          int64
# Positiveness          int64
# Speechiness           int64
# Liveness              int64
# Acousticness          int64
# Instrumentalness      int64
# dtype: object

# %%
df_c['Release Date']=pd.to_datetime(df_c['Release Date'],format='%Y')
# Out:
# C:\Users\rajat\AppData\Local\Temp\ipykernel_6096\543438403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['Release Date']=pd.to_datetime(df_c['Release Date'],format='%Y')

# %%
df_c.dtypes
# Out:
# artist                      object
# song                        object
# emotion                     object
# variance                   float64
# Genre                       object
# Release Date        datetime64[ns]
# Key                         object
# Tempo                        int64
# Loudness                   float64
# Explicit                    object
# Popularity                   int64
# Energy                       int64
# Danceability                 int64
# Positiveness                 int64
# Speechiness                  int64
# Liveness                     int64
# Acousticness                 int64
# Instrumentalness             int64
# dtype: object

# %%
df_c
# Out:
#                               artist                   song  emotion  \
# 0                               ABBA  She's My Kind Of Girl      joy
# 1                               ABBA       Andante, Andante     love
# 2                               ABBA         As Good As New  sadness
# 3                               ABBA                   Bang      joy
# 4                               ABBA       Bang-A-Boomerang      joy
# ...                              ...                    ...      ...
# 236983                  (Eri Sasaki)        Gate Of Steiner  sadness
# 236984             (Elena Tsagrinou)              El Diablo     love
# 236985                  (Dima Bilan)                Believe      joy
# 236986                   (Ani Lorak)             Shady Lady      joy
# 236987    (Alla Pugacheva) & 50 Cent    Позови меня P.I.M.P    anger
#
#         variance                    Genre Release Date     Key  Tempo  \
# 0       0.447619                      pop   2014-01-01   F Maj    128
# 1       0.202222                      pop   1980-01-01  A# Maj    102
# 2       0.300881                      pop   1979-01-01   E Maj    139
# 3       0.355000                      pop   1975-01-01   F Maj    132
# 4       0.355000                      pop   1975-01-01   F Maj    132
# ...          ...                      ...          ...     ...    ...
# 236983  0.833514  Unknown,Unknown,Unknown   2018-01-01   D min    148
# 236984  0.833514  Unknown,Unknown,Unknown   2021-01-01   A min    114
# 236985  0.833514  Unknown,Unknown,Unknown   2009-01-01   C min    134
# 236986  0.833514  Unknown,Unknown,Unknown   2009-01-01  F# min    128
# 236987  0.833514  Unknown,Unknown,Unknown   2023-01-01   B Maj    175
#
#         Loudness Explicit  Popularity  Energy  Danceability  Positiveness  \
# 0          -6.00       No          31      78            56            60
# 1         -10.72       No          59      36            52            38
# 2          -5.70       No          50      78            85            97
# 3          -3.00       No          52      76            50            89
# 4          -3.00       No          52      76            50            89
# ...          ...      ...         ...     ...           ...           ...
# 236983     -6.44       No          41      61            41            37
# 236984     -7.78       No          51      66            66            62
# 236985     -6.72       No          36      73            55            24
# 236986    -13.00       No          37      70            71            77
# 236987     -7.15       No          54      91            42            32
#
#         Speechiness  Liveness  Acousticness  Instrumentalness
# 0                 3        31             7                 0
# 1                 2         7            68                 0
# 2                 3         8            20                 2
# 3                 3        32             3                 0
# 4                 3        32             3                 0
# ...             ...       ...           ...               ...
# 236983            4        14            20                 0
# 236984           13        84             0                 0
# 236985            5        22             5                 0
# 236986            5         7             5                 0
# 236987            8        38             0                84
#
# [236980 rows x 18 columns]

# %%
#Can you identify how many duplicates values are there
c = df_c.duplicated().sum()
c
# Out:
# 2

# %%
df_c.drop_duplicates()
# Out:
#                               artist                   song  emotion  \
# 0                               ABBA  She's My Kind Of Girl      joy
# 1                               ABBA       Andante, Andante     love
# 2                               ABBA         As Good As New  sadness
# 3                               ABBA                   Bang      joy
# 4                               ABBA       Bang-A-Boomerang      joy
# ...                              ...                    ...      ...
# 236983                  (Eri Sasaki)        Gate Of Steiner  sadness
# 236984             (Elena Tsagrinou)              El Diablo     love
# 236985                  (Dima Bilan)                Believe      joy
# 236986                   (Ani Lorak)             Shady Lady      joy
# 236987    (Alla Pugacheva) & 50 Cent    Позови меня P.I.M.P    anger
#
#         variance                    Genre Release Date     Key  Tempo  \
# 0       0.447619                      pop   2014-01-01   F Maj    128
# 1       0.202222                      pop   1980-01-01  A# Maj    102
# 2       0.300881                      pop   1979-01-01   E Maj    139
# 3       0.355000                      pop   1975-01-01   F Maj    132
# 4       0.355000                      pop   1975-01-01   F Maj    132
# ...          ...                      ...          ...     ...    ...
# 236983  0.833514  Unknown,Unknown,Unknown   2018-01-01   D min    148
# 236984  0.833514  Unknown,Unknown,Unknown   2021-01-01   A min    114
# 236985  0.833514  Unknown,Unknown,Unknown   2009-01-01   C min    134
# 236986  0.833514  Unknown,Unknown,Unknown   2009-01-01  F# min    128
# 236987  0.833514  Unknown,Unknown,Unknown   2023-01-01   B Maj    175
#
#         Loudness Explicit  Popularity  Energy  Danceability  Positiveness  \
# 0          -6.00       No          31      78            56            60
# 1         -10.72       No          59      36            52            38
# 2          -5.70       No          50      78            85            97
# 3          -3.00       No          52      76            50            89
# 4          -3.00       No          52      76            50            89
# ...          ...      ...         ...     ...           ...           ...
# 236983     -6.44       No          41      61            41            37
# 236984     -7.78       No          51      66            66            62
# 236985     -6.72       No          36      73            55            24
# 236986    -13.00       No          37      70            71            77
# 236987     -7.15       No          54      91            42            32
#
#         Speechiness  Liveness  Acousticness  Instrumentalness
# 0                 3        31             7                 0
# 1                 2         7            68                 0
# 2                 3         8            20                 2
# 3                 3        32             3                 0
# 4                 3        32             3                 0
# ...             ...       ...           ...               ...
# 236983            4        14            20                 0
# 236984           13        84             0                 0
# 236985            5        22             5                 0
# 236986            5         7             5                 0
# 236987            8        38             0                84
#
# [236978 rows x 18 columns]

# %%
df_c.drop_duplicates(inplace=True)
# Out:
# C:\Users\rajat\AppData\Local\Temp\ipykernel_6096\1151430490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c.drop_duplicates(inplace=True)

# %%
df_c
# Out:
#                               artist                   song  emotion  \
# 0                               ABBA  She's My Kind Of Girl      joy
# 1                               ABBA       Andante, Andante     love
# 2                               ABBA         As Good As New  sadness
# 3                               ABBA                   Bang      joy
# 4                               ABBA       Bang-A-Boomerang      joy
# ...                              ...                    ...      ...
# 236983                  (Eri Sasaki)        Gate Of Steiner  sadness
# 236984             (Elena Tsagrinou)              El Diablo     love
# 236985                  (Dima Bilan)                Believe      joy
# 236986                   (Ani Lorak)             Shady Lady      joy
# 236987    (Alla Pugacheva) & 50 Cent    Позови меня P.I.M.P    anger
#
#         variance                    Genre Release Date     Key  Tempo  \
# 0       0.447619                      pop   2014-01-01   F Maj    128
# 1       0.202222                      pop   1980-01-01  A# Maj    102
# 2       0.300881                      pop   1979-01-01   E Maj    139
# 3       0.355000                      pop   1975-01-01   F Maj    132
# 4       0.355000                      pop   1975-01-01   F Maj    132
# ...          ...                      ...          ...     ...    ...
# 236983  0.833514  Unknown,Unknown,Unknown   2018-01-01   D min    148
# 236984  0.833514  Unknown,Unknown,Unknown   2021-01-01   A min    114
# 236985  0.833514  Unknown,Unknown,Unknown   2009-01-01   C min    134
# 236986  0.833514  Unknown,Unknown,Unknown   2009-01-01  F# min    128
# 236987  0.833514  Unknown,Unknown,Unknown   2023-01-01   B Maj    175
#
#         Loudness Explicit  Popularity  Energy  Danceability  Positiveness  \
# 0          -6.00       No          31      78            56            60
# 1         -10.72       No          59      36            52            38
# 2          -5.70       No          50      78            85            97
# 3          -3.00       No          52      76            50            89
# 4          -3.00       No          52      76            50            89
# ...          ...      ...         ...     ...           ...           ...
# 236983     -6.44       No          41      61            41            37
# 236984     -7.78       No          51      66            66            62
# 236985     -6.72       No          36      73            55            24
# 236986    -13.00       No          37      70            71            77
# 236987     -7.15       No          54      91            42            32
#
#         Speechiness  Liveness  Acousticness  Instrumentalness
# 0                 3        31             7                 0
# 1                 2         7            68                 0
# 2                 3         8            20                 2
# 3                 3        32             3                 0
# 4                 3        32             3                 0
# ...             ...       ...           ...               ...
# 236983            4        14            20                 0
# 236984           13        84             0                 0
# 236985            5        22             5                 0
# 236986            5         7             5                 0
# 236987            8        38             0                84
#
# [236978 rows x 18 columns]

# %%
#Task1: Average popularity by Emotion
#Find which emotions are associated with popular songs
avg_emotion = df_c.groupby('emotion')['Popularity'].mean().sort_values(ascending=False)
print(avg_emotion)
# Out:
# emotion
# angry       56.000000
# True        41.142857
# anger       40.608180
# joy         40.006839
# surprise    39.807033
# fear        39.789883
# sadness     39.733065
# love        39.500937
# thirst      28.000000
# pink        21.000000
# Name: Popularity, dtype: float64

# %%
#Average Energy and Danceability by Genre
#Find out the most energetic and danceable genre
avg_energy_dance = df_c.groupby('Genre')[['Energy','Danceability']].mean().sort_values(by=['Energy','Danceability'])

# %%
avg_energy_dance
# Out:
#                                           Energy  Danceability
# Genre
# piano,minimalism,post-rock                   0.0          41.0
# female,sexy,C                                1.0           7.0
# female,late night,contemporary classical     1.0          12.0
# gregorian,Classical,Tinsel                   1.0          27.0
# nick and norah,irish,melancholy              1.0          69.0
# ...                                          ...           ...
# punk,street punk,hardcore                   99.5          40.0
# noise rock,experimental,noise              100.0          24.0
# hardcore,hatecore,i hate people too        100.0          35.0
# eurobeat,anime,Initial D                   100.0          48.0
# noise,industrial,experimental              100.0          50.0
#
# [2562 rows x 2 columns]

# %%
#Top Artists by sound count
artist = df_c.groupby('artist')['song'].count().sort_values(ascending=False)
print(artist)
# Out:
# artist
# Genius English Translations    1604
# Lil Wayne                       753
# Juice WRLD                      647
# Chris Brown                     589
# Gucci Mane                      522
#                                ...
# John That                         1
# John Taylor                       1
# John Tavener                      1
# John Tartaglia & Rick Lyon        1
# {Parentheses}                     1
# Name: song, Length: 30607, dtype: int64

# %%
songs = df_c[df_c['artist']=='Shawn Mendes']
songs
# Out:
#              artist                                               song  \
# 99236  Shawn Mendes                      Theres Nothing Holdin Me Back
# 99237  Shawn Mendes                                        In My Blood
# 99238  Shawn Mendes                                   Treat You Better
# 99239  Shawn Mendes                                      Lost in Japan
# 99240  Shawn Mendes                                 If I Cant Have You
# ...             ...                                                ...
# 99319  Shawn Mendes            Where Were You in the Morning? Acoustic
# 99320  Shawn Mendes                                            LeeAnne
# 99321  Shawn Mendes                                             Lonely
# 99322  Shawn Mendes  I Dont Even Know Your Name / Aftertaste / Kid ...
# 99323  Shawn Mendes                                        Youth Remix
#
#        emotion  variance Genre  Release Date     Key  Tempo  Loudness  \
# 99236      joy  0.833514   pop          2017   B min    122     -4.06
# 99237     fear  0.833514   pop          2018   F Maj    140     -7.32
# 99238     love  0.833514   pop          2017  A# min     83     -4.08
# 99239  sadness  0.833514   pop          2018  A# Maj    105     -6.78
# 99240  sadness  0.833514   pop          2019   D Maj    124     -4.20
# ...        ...       ...   ...           ...     ...    ...       ...
# 99319      joy  0.833514   pop          2018   G Maj     88     -7.47
# 99320      joy  0.833514   pop          2017  A# min     83     -4.08
# 99321  sadness  0.833514   pop          2021  A# min     75     -6.66
# 99322      joy  0.833514   pop          2016   D Maj    170     -6.10
# 99323  sadness  0.833514   pop          2018  F# min    100     -6.91
#
#       Explicit  Popularity  Energy  Danceability  Positiveness  Speechiness  \
# 99236       No          86      81            87            97            6
# 99237       No          74      71            62            49            7
# 99238       No          85      82            44            75           34
# 99239       No          71      74            71            42           37
# 99240       No          73      82            69            87            6
# ...        ...         ...     ...           ...           ...          ...
# 99319       No          56      52            72            47            6
# 99320       No          86      82            44            75           34
# 99321       No          11      74            74            74            9
# 99322       No          31      79            38            47            5
# 99323       No          31      58            61            32            6
#
#        Liveness  Acousticness  Instrumentalness
# 99236         8            38                 0
# 99237        13             6                 0
# 99238        11            11                 0
# 99239        11            26                 0
# 99240        13            49                 0
# ...         ...           ...               ...
# 99319        10            55                 0
# 99320        11            11                 0
# 99321         5             2                 0
# 99322        56             7                 0
# 99323         8            60                 0
#
# [88 rows x 18 columns]

# %%
loudest_artist = df_c.groupby('artist')['Loudness'].mean().sort_values(ascending=False)
loudest_artist
# Out:
# artist
# 1 800 PAIN                   2.49
# MC MENTAL                    1.68
# Culture Shock                1.65
# Bear bear & friends          1.59
# Gill Chang & Rahn Harper     1.59
#                             ...
# Iseo & Dodosound           -39.05
# Pizzicato Five             -39.22
# A-Q & M.I Abaga            -42.43
# Retrospect                 -43.98
# East Warren Buck           -44.74
# Name: Loudness, Length: 30607, dtype: float64

# %%
loudest_song = df_c[['song','Loudness']].sort_values(by='Loudness',ascending=False).head(10)
print(loudest_song)
# Out:
#                                      song  Loudness
# 79934   Your Pretty Face Is Going to Hell      3.74
# 8168    Your Pretty Face Is Going To Hell      3.74
# 236296                               LURK      3.51
# 146026                      MONDAY GUNDAY      2.62
# 94563                              BOGATA      2.33
# 146003                   DONT TREAD ON ME      2.32
# 100919                          Red Light      2.04
# 8106                           Death Trip      1.96
# 100945                         TERRAFXRM.      1.83
# 101005                  MAKING A KILLING.      1.82

# %%
#Top 5 emotions by average positiveness
df_c.groupby('emotion')['Positiveness'].mean().sort_values(ascending=False).head(5)
# Out:
# emotion
# thirst      54.000000
# joy         49.537835
# love        48.922434
# anger       48.469697
# surprise    47.714408
# Name: Positiveness, dtype: float64

# %%
#How many songs released by an artist in a year
df_c.groupby(['artist','Release Date'])['song'].count().sort_values(ascending=False)
# Out:
# artist                       Release Date
# Genius English Translations  2019-01-01      393
# Juice WRLD                   2020-01-01      208
# Genius English Translations  2021-01-01      182
#                              2022-01-01      175
# Juice WRLD                   2019-01-01      166
#                                             ...
# Jimmy Cliff                  2022-01-01        1
# Jimmy Cross                  2016-01-01        1
# Jimmy Dean                   1967-01-01        1
#                              2004-01-01        1
# {Parentheses}                2017-01-01        1
# Name: song, Length: 71040, dtype: int64

# %%
#how many are in emotion joy
joy = df_c[df_c['emotion']=='joy']
print(joy)
# Out:
#                  artist                   song emotion  variance  \
# 0                  ABBA  She's My Kind Of Girl     joy  0.447619
# 3                  ABBA                   Bang     joy  0.355000
# 4                  ABBA       Bang-A-Boomerang     joy  0.355000
# 11                 ABBA          Dancing Queen     joy  0.169307
# 12                 ABBA            Disillusion     joy -0.022531
# ...                 ...                    ...     ...       ...
# 236978    (Olga Buzova)      Not Enough For Me     joy  0.833514
# 236981      (Ivan Dorn)                Collaba     joy  0.833514
# 236982      (Ivan Dorn)                Beverly     joy  0.833514
# 236985     (Dima Bilan)                Believe     joy  0.833514
# 236986      (Ani Lorak)             Shady Lady     joy  0.833514
#
#                           Genre Release Date     Key  Tempo  Loudness  \
# 0                           pop   2014-01-01   F Maj    128     -6.00
# 3                           pop   1975-01-01   F Maj    132     -3.00
# 4                           pop   1975-01-01   F Maj    132     -3.00
# 11                          pop   1976-01-01   A Maj    101     -6.51
# 12                          pop   1973-01-01   G Maj    142    -12.90
# ...                         ...          ...     ...    ...       ...
# 236978  Unknown,Unknown,Unknown   2017-01-01  A# min    117     -5.85
# 236981  Unknown,Unknown,Unknown   2018-01-01   B min    152     -9.57
# 236982  Unknown,Unknown,Unknown   2018-01-01   D Maj    113     -6.46
# 236985  Unknown,Unknown,Unknown   2009-01-01   C min    134     -6.72
# 236986  Unknown,Unknown,Unknown   2009-01-01  F# min    128    -13.00
#
#        Explicit  Popularity  Energy  Danceability  Positiveness  Speechiness  \
# 0            No          31      78            56            60            3
# 3            No          52      76            50            89            3
# 4            No          52      76            50            89            3
# 11           No          87      87            54            75            4
# 12           No          36      37            58            44            3
# ...         ...         ...     ...           ...           ...          ...
# 236978       No           6      62            75            54           10
# 236981      Yes          16      88            47            13           27
# 236982       No          19      77            73            68            5
# 236985       No          36      73            55            24            5
# 236986       No          37      70            71            77            5
#
#         Liveness  Acousticness  Instrumentalness
# 0             31             7                 0
# 3             32             3                 0
# 4             32             3                 0
# 11            79            36                 0
# 12            11            50                 0
# ...          ...           ...               ...
# 236978        14            37                 0
# 236981         6             8                 5
# 236982        22             0                 5
# 236985        22             5                 0
# 236986         7             5                 0
#
# [91528 rows x 18 columns]

# %%
#what year has the highest number of hit songs
df_c.groupby(df_c['Release Date'].dt.year)['song'].sum().sort_values(ascending=False)
# Out:
# Release Date
# 1965    Winter WonderlandAll That I WantHe Touched MeI...
# 2011    Who Am ICamp GranadaThe Psychotic Legend Of Un...
# 1999    Welcome My SonI Love You Enough To Let You GoI...
# 2019    We Wish You A Merry ChristmasYou'll Never See ...
# 1957    Walk Hand In HandBillie BluesComes LoveGee Bab...
#                               ...
# 1954    All Of MeAir Mail SpecialMessage To My MotherS...
# 1953    A Woman's TouchBeyond The SunsetCrazy HeartHal...
# 2010    A Little Bit MoreAlternate EndingPut A Little ...
# 1948    A Fella With An UmbrellaIt Only Happens When I...
# 1962    409Swingin' Down The LaneSwinging on A StarFix...
# Name: song, Length: 93, dtype: object

# %%
#Key used max for in different generes
key_used = df_c.groupby('Genre')['Key'].max().sort_values(ascending=False)
print(key_used)
# Out:
# Genre
# emo,indie,acoustic                    G# min
# anime,Unknown,Unknown                 G# min
# rnb,slow jams,Ginuwine                G# min
# acoustic,Unknown,Unknown              G# min
# country,classic country,50s           G# min
#                                        ...
# Eurovision,dance,2010s                 A Maj
# Fave,Unknown,Unknown                   A Maj
# beats,frauen und technik,Unknown       A Maj
# fip,eclectonia,Unknown                 A Maj
# gospel,black gospel,Classic Gospel     A Maj
# Name: Key, Length: 2562, dtype: object
